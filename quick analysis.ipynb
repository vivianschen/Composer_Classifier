# %% [markdown]
# Analyzing musical characteristics of Chopin, Liszt, Schubert, and Schumann! Using 10 MIDI samples of their works performed by participants in the e-competition @ UMinn (http://www.piano-e-competition.com/ecompetition/midiinstructions.asp), randomly trimmed to 10 seconds each. Features extracted by jSymbolic software.

# %%
import numpy as np
import csv
import pandas as pd

# %%
data = pd.read_csv("C:/Users/Chen/Desktop/MIR/New folder/select_features.csv")

# %%
data
# Out:
#     Composer  Number_of_Pitches  Number_of_Pitch_Classes  \
# 0     Chopin                 46                       11
# 1     Chopin                 29                        9
# 2     Chopin                 26                       10
# 3     Chopin                 30                       10
# 4     Chopin                 31                       10
# 5     Chopin                 34                       11
# 6     Chopin                 41                       11
# 7     Chopin                 18                        9
# 8     Chopin                 22                        8
# 9     Chopin                 44                       12
# 10     Liszt                 22                       11
# 11     Liszt                 66                       12
# 12     Liszt                 32                       11
# 13     Liszt                 21                        8
# 14     Liszt                 27                        9
# ...

# %%
data_short = data[["Composer", "Number_of_Pitches", "Range", "Mean_Pitch", "Most_Common_Pitch", "Average_Length_of_Melodic_Arcs"]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
grr = pd.plotting.scatter_matrix(data, figsize=(15, 15), marker='o')

# %%
data_short['Composer'] = data_short['Composer'].astype('category')
# Out:
# C:\Users\Chen\Anaconda3\Lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dict( enumerate(data_short['Composer'].cat.categories) )
# Out:
# {0: 'Chopin', 1: 'Liszt', 2: 'Schubert', 3: 'Schumann'}

# %%
data_short['Composer'] = data_short['Composer'].cat.codes
# Out:
# C:\Users\Chen\Anaconda3\Lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_short
# Out:
#     Composer  Number_of_Pitches  Range  Mean_Pitch  Most_Common_Pitch  \
# 0          0                 46     63          68                 85
# 1          0                 29     48          61                 58
# 2          0                 26     40          62                 72
# 3          0                 30     40          60                 51
# 4          0                 31     60          78                 85
# 5          0                 34     57          62                 72
# 6          0                 41     57          62                 72
# 7          0                 18     34          57                 61
# 8          0                 22     52          59                 56
# 9          0                 44     57          59                 59
# 10         1                 22     33          66                 75
# 11         1                 66     72          63                 59
# ...

# %%
grr = pd.plotting.scatter_matrix(data_short, figsize=(15, 15), marker='o')

# %%
import seaborn as sns
import pandas as pd
g = sns.pairplot(data_short, hue="Composer",
                 hue_order=data_short.Composer.cat.categories,
                 palette="hls")
g

# %%
data.groupby("Composer").plot(legend = False)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

plt.ylim(0, 250)
plt.show()

# %%
import seaborn as sns

# %%
#fig, ax1  = plt.subplots(2, 2, sharex=True, sharey=True)


sns.stripplot(x=data["Composer"], y = data["Range"], jitter = True, palette = "hls")

# %%
sns.stripplot(x=data["Composer"], y = data["Mean_Pitch"], jitter = True, palette = "hls")

# %%
sns.stripplot(x=data["Composer"], y = data["Average_Length_of_Melodic_Arcs"], jitter = True, palette = "hls")

# %%
sns.stripplot(x=data["Composer"], y = data["Importance_of_Bass_Register"], jitter = True, palette = "hls")

# %%
sns.stripplot(x=data["Composer"], y = data["Importance_of_High_Register"], jitter = True, palette = "hls")
